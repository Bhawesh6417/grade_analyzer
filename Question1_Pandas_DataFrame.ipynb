# %% [markdown]
# # Create a Student DataFrame using the given data

# %%
import pandas as pd

data = {
    "StudentID": [101,102,103,104,105,106,107,108,109,110],
    "Name": ["Alice","Bob","Charlie","Diana","Ethan","Fiona","George","Hannah","Ivan","Julia"],
    "Age": [20,21,19,22,20,21,23,19,22,20],
    "Marks": [88,75,92,65,78,85,70,95,60,80],
    "Grade": ["A","B","A","C","B","A","B","A","C","B"]
}

df = pd.DataFrame(data)
df

# %% [markdown]
# # Save the DataFrame as a CSV file named students.csv

# %%
df.to_csv("students.csv", index=False)

# %% [markdown]
# # Reload students.csv into a new DataFrame

# %%
df_new = pd.read_csv("students.csv")
df_new

# %% [markdown]
# # Display the first 3 rows of the DataFrame

# %%
df_new.head(3)

# %% [markdown]
# # Display the statistical summary of numerical columns

# %%
df_new.describe()

# %% [markdown]
# # Explore dataset shape, data types, and detailed info

# %%
print("Shape of DataFrame:", df_new.shape)
print("\nData Types:")
print(df_new.dtypes)
print("\nDataFrame Info:")
df_new.info()
